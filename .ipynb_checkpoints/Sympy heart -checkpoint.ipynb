# %%
# %matplotlib inline
from sympy import *
from sympy.plotting import plot_parametric
from sympy.abc import t

# %%
plot_parametric(16*sin(t)**3, 13*cos(t)-5*cos(2*t)-2*cos(3*t)-cos(4*t), (t,0,2*pi))
