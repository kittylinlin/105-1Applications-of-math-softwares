# %% [markdown]
# ## 健康平均餘命
# * [資料來源](http://happyindex.dgbas.gov.tw/Statistics.htm?y=201602)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
xlabel('year')
ylabel('year old')
year = arange(2001, 2015, 1)
woman = (71.7, 71.7, 72.3, 72.0, 72.2, 72.7, 72.7, 72.9, 73.0, 73.2, 72.7, 73.3, 73.6, 73.4)
man = (66.7, 66.9, 67.6, 67.1, 67.1, 67.6, 67.9, 68.0, 68.3, 68.5, 67.8, 68.7, 68.9, 68.7)
average = (69.0, 69.2, 69.8, 69.4, 69.5, 70.0, 70.2, 70.3, 70.5, 70.8, 70.1, 70.9, 71.1, 71.0)
plot( year, woman, 'r', year, man, 'b', year, average, 'g')
