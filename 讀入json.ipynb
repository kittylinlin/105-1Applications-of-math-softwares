# %% [markdown]
# ## [臺北市開放認養動物](http://data.taipei/opendata/datalist/datasetMeta?oid=6a3e862a-e1cb-4e44-b989-d35609559463)

# %%
import pandas as pd

# %%
df = pd.read_json('animal.json')
df
# Out:
#      AcceptNum Age AnimalAnlong Bodyweight Build ChildreAnlong  \
# 0    105112803  成年                             中
# 1    105112611  年輕                             中
# 2    105112205  成年                             中
# 3    105111807  成年                             中
# 4    105111806  成年                             中
# 5    105111602  成年                             中
# 6    105111505  成年                             中
# 7    105111403  成年                             中
# 8    105111303  成年                             中
# 9    105111003  成年                             中
# 10   105111002  成年                             中
# 11   105110704  成年                             中
# 12   105110502  成年                             中
# 13   105110315  幼齡                             幼
# 14   105110309  成年                             中
# 15   105110302  年輕                             幼
# 16   105110313  成年                             中
# 17   105103105  成年                             中
# ...

# %%
pd.re
